# %%
import openai
import asyncio
import os
import pandas as pd  # For data handling, like reading from Excel
from openai import AsyncOpenAI  # Asynchronous client from the new OpenAI SDK
from rapidfuzz import fuzz
from dotenv import load_dotenv
import json
import configparser  # For reading configuration files
import re

import nest_asyncio
nest_asyncio.apply()

# %%
# Load .env variables
load_dotenv()

openai_api_key = os.getenv("OPENAI_API_KEY")
assistant_id     = os.getenv("ASSISTANT_ID")
healmatch_id     = os.getenv("HEALMATCH_ID")
harmonizer_id    = os.getenv("HARMONIZER_ID")

# sanity check (optional)
if not all([openai_api_key, assistant_id, healmatch_id, harmonizer_id]):
    raise RuntimeError("Missing one or more OpenAI env vars")

client = AsyncOpenAI(api_key=openai_api_key)

# %%
# Load configuration file
config = configparser.ConfigParser()
config.read('config_prestep.ini')

# Retrieve file paths and column names from config
input_file = config['Files']['input_file']
input_worksheet = config['Files']['input_worksheet']
crf_column = config['Columns']['crf_column']
variable_column = config['Columns']['variable_column']
description_column = config['Columns']['description_column']

# %%
# Set assistant instructions
crf_id = config['Instructions']['crf_id_prestep']
matching_instruction = config['Instructions']['matching_instruction']
form_harmonizer_prompt = config['Instructions']['form_harmonizer']

# %%
# Load the data dictionary from Excel file
data_dict_df = pd.read_excel(input_file, sheet_name=input_worksheet)

# Select only the relevant columns
data_dict_df = data_dict_df[[crf_column, variable_column, description_column]]

# Display the first few rows of the loaded data
print("Loaded Data Dictionary:")
print(data_dict_df.head())

# Convert the DataFrame into record dicts
records = data_dict_df.to_dict(orient='records')

# Take the first record and build the payload
first_row = records[0]
payload = {
    "crf_name": first_row[crf_column],
    "variable_name": first_row[variable_column],
    "description": first_row[description_column]
}
# Out:
# Loaded Data Dictionary:
#          Form Name Variable / Field Name     Field Label
# 0  phone_screening                   pid  Participant ID
# 1  phone_screening                   mrn             MRN
# 2  phone_screening              acrostic        Acrostic
# 3  phone_screening        interview_date  Interview Date
# 4  phone_screening           interviewer     Interviewer

# %%
def parse_llm_json(full, crf_name):
    try:
        data = json.loads(full)
        refined = data.get("crf_name", crf_name).strip()
        rationale = data.get("rationale", "").strip()
        return refined, rationale, full
    except json.JSONDecodeError:
        print("\n[ERROR] JSON decode error. Full response was:\n", full)
        return crf_name, "", full

def normalize_name(name):
    # Lowercase, remove punctuation, and drop generic words like "form"
    name = name.lower()
    name = re.sub(r'form|log|assessment|information|status', '', name)  # Remove extra generic words
    name = re.sub(r'[^a-z0-9\s]', '', name)  # Remove punctuation
    name = re.sub(r'\s+', ' ', name)         # Collapse whitespace
    return name.strip()

def auto_cluster_names(names, threshold=70):
    """
    Clusters similar names using fuzzy matching and assigns the most frequent as canonical.
    Returns a dict: {original_name: canonical_name}
    """
    clusters = []
    mapping = {}
    name_counts = pd.Series(names).value_counts().to_dict()
    normalized_names = {name: normalize_name(name) for name in names}
    for name in names:
        found_cluster = False
        for cluster in clusters:
            if any(fuzz.ratio(normalized_names[name], normalized_names[c]) >= threshold for c in cluster):
                cluster.append(name)
                found_cluster = True
                break
        if not found_cluster:
            clusters.append([name])
    for cluster in clusters:
        canonical = pd.Series(cluster).map(lambda x: name_counts.get(x, 0)).idxmax()
        for name in cluster:
            mapping[name] = canonical
    return mapping

# %%
def detect_heal_cde_acronym(varname: str):
    """
    Scan a variable name for HEAL Core CDE / CRF acronyms.
    Returns a family-level or specific-level hint, or None.
    """
    if not isinstance(varname, str):
        return None

    name = varname.lower()

    # --- Unambiguous CRFs ---
    if name.startswith("bpi") or "bpi" in name:
        return "Brief Pain Inventory (BPI)"

    if "peg" in name:
        return "PEG Pain"

    if name.startswith("taps") or "taps" in name:
        return "TAPS Pain"

    if name.startswith("pedsql") or "pedsql" in name:
        return "PedsQL"

    if "whoqol" in name:
        return "WHOQOL2"

    # --- Family-level (ambiguous) CRFs ---
    if name.startswith("phq") or "phq" in name:
        return "PHQ"   # PHQ2, PHQ8, PHQ9

    if name.startswith("gad") or "gad" in name:
        return "GAD"   # GAD2, GAD7

    if name.startswith("pcs") or "pcs" in name:
        return "PCS"   # PCS6, PCS13, etc.

    if name.startswith("promis") or "promis" in name:
        return "PROMIS"   # PF Pain, Sleep Disturbance, etc.

    # No match found
    return None

# %%
# Helper set 1 API call
async def refine_crf_name_with_variables(client, variable_names, crf_name, descriptions, acronym_hint=None):
    """
    Calls OpenAI to refine/formulate a unique, concise CRF name 
    based on the original CRF name, variable names, descriptions,
    and Python-detected CRF acronym (if available).
    """

    # Build acronym text ONLY if we have one
    acronym_text = ""
    if acronym_hint:
        acronym_text = f"\nAcronym hint detected from variable name: {acronym_hint}\n"

    prompt = (
        f"{crf_id}\n\n"
        "Please respond in JSON with keys "
        "`crf_name` and `rationale` only. Do not wrap in markdown.\n\n"
        f"Variable names: {variable_names}\n"
        f"Original form name: {crf_name}\n"
        f"Descriptions: {descriptions}\n"
        f"{acronym_text}"
    )

    response = await client.chat.completions.create(
        model="gpt-4.1-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0.5,
    )

    full = response.choices[0].message.content.strip()
    print("\n--- Full Prestep Response ---\n", full, "\n--- End ---\n")

    return parse_llm_json(full, crf_name)


async def refine_with_retry(client, var, crf, desc, acronym_hint, tries=5):
    """
    Retry wrapper for prestep refinement.
    Now includes acronym_hint as part of the call.
    """
    backoff = 1
    for attempt in range(1, tries + 1):
        try:
            return await refine_crf_name_with_variables(client, var, crf, desc, acronym_hint)
        except Exception as e:
            msg = str(e).lower()
            is_rate = (
                "rate limit" in msg or
                "429" in msg or
                (hasattr(e, "code") and e.code == "rate_limit_exceeded")
            )

            if is_rate:
                print(f"[rate limit] prestep attempt {attempt}, sleeping {backoff}s")
            else:
                print(f"[warning] prestep failed attempt {attempt}: {e}")

            if attempt == tries:
                return crf, "", ""

            await asyncio.sleep(backoff)
            backoff *= 2


# loop call row-by-row, run prestep
async def run_prestep(client, df, chunk_size=50):
    """
    Runs prestep refinement in batches.
    Now passes CHUNKED acronym hints along with other fields.
    """
    all_r, all_rat, all_full = [], [], []

    for start in range(0, len(df), chunk_size):
        chunk = df.iloc[start:start+chunk_size]

        tasks = [
            refine_with_retry(
                client,
                row[variable_column],
                row[crf_column],
                row[description_column],
                row["CDE Acronym Finder"]   # <--- THE NEW PIECE
            )
            for _, row in chunk.iterrows()
        ]

        results = await asyncio.gather(*tasks)
        names, rats, fulls = zip(*results)

        all_r.extend(names)
        all_rat.extend(rats)
        all_full.extend(fulls)

        await asyncio.sleep(1)

    df["Refined CRF Name"], df["Rationale"], df["Full Response"] = all_r, all_rat, all_full
    return df


# Example main block (unchanged)
async def main():
    # Step 1: refine each CRF name
    refined_df = await run_prestep(client, data_dict_df)

    print("After prestep, here’s a sample:")
    print(refined_df[[crf_column, "Refined CRF Name"]].head())

# %%
# 1) Define the function schema
harmonize_function = {
    "name": "harmonize_crf_names",
    "description": "Map each original CRF name to a single harmonized label",
    "parameters": {
        "type": "object",
        "properties": {
            "mapping": {
                "type": "object",
                "description": "Keys are the original form names; values are the harmonized labels",
                "additionalProperties": { "type": "string" }
            }
        },
        "required": ["mapping"]
    }
}

# 2) Harmonizer helper with debug prints and fallbacks
def batcher(seq, size=20):
    """Yield successive size-sized chunks from seq."""
    for pos in range(0, len(seq), size):
        yield seq[pos:pos + size]

async def harmonize_crf_names_step(client, refined_df, batch_size=20):
    # Build and dedupe the payload
    seen = set()
    unique_entries = []
    for orig, rat in zip(refined_df["Refined CRF Name"], refined_df["Rationale"]):
        key = (orig, rat)
        if key not in seen:
            seen.add(key)
            unique_entries.append({"original": orig, "rationale": rat})

    if not unique_entries:
        refined_df["Canonical CRF Name"] = refined_df["Refined CRF Name"]
        print("[Harmonizer] No entries to harmonize, using identity mapping.")
        return refined_df

    combined_mapping = {}

    # Batch and harmonize!
    for batch_num, batch in enumerate(batcher(unique_entries, size=batch_size), start=1):
        print(f"\n[Harmonizer] Sending batch {batch_num} of {len(batch)}:")
        for e in batch:
            print("   ", e)

        response = await client.chat.completions.create(
            model="gpt-4.1-mini",
            messages=[
                {"role": "system", "content": config["Instructions"]["form_harmonizer"]},
                {"role": "user", "content": json.dumps(batch)}
            ],
            functions=[harmonize_function],
            function_call={"name": "harmonize_crf_names"},
            temperature=0
        )

        choice = response.choices[0].message
        print("\n[Harmonizer] Raw model message:")
        print(choice)

        # Verify the function name
        if choice.function_call:
            print(f"[Harmonizer] Function called: {choice.function_call.name}")
        else:
            print("[Harmonizer] No function_call detected")

        # Parse the returned arguments
        mapping = {}
        if choice.function_call:
            raw_args = choice.function_call.arguments
            print("[Harmonizer] Raw function_call.arguments:", raw_args)
            try:
                args = json.loads(raw_args)
                if "mapping" in args and isinstance(args["mapping"], dict):
                    mapping = args["mapping"]
                else:
                    mapping = args
            except json.JSONDecodeError as e:
                print("[Harmonizer] JSON decode error:", e)

        # Fallback to identity if mapping is empty for this batch
        if not mapping:
            print("[Harmonizer] Empty mapping for this batch; defaulting to identity.")
            mapping = {e['original']: e['original'] for e in batch}

        print("\n[Harmonizer] Parsed mapping (original → harmonized):")
        for orig, canon in mapping.items():
            print(f"    '{orig}' -> '{canon}'")

        # Combine batch mapping into all mappings
        combined_mapping.update(mapping)

    # Apply the combined mapping
    refined_df["Canonical CRF Name"] = refined_df["Refined CRF Name"].map(lambda x: combined_mapping.get(x, x))

    for col in ["Refined CRF Name", "Canonical CRF Name"]:
        refined_df[col] = refined_df[col].apply(lambda x: ", ".join(x) if isinstance(x, list) else x)

    print("\n[Harmonizer] Final Canonical CRF Name results:")
    print(
        refined_df[["Refined CRF Name", "Canonical CRF Name"]]
        .drop_duplicates()
        .reset_index(drop=True)
    )

    # Auto-cluster for final canonical name
    print("\n[Auto-Cluster] Clustering Canonical CRF Names for final deduplication...")

    unique_canonicals = refined_df["Canonical CRF Name"].unique()
    auto_map = auto_cluster_names(unique_canonicals, threshold=70)

    refined_df["Final Canonical CRF Name"] = refined_df["Canonical CRF Name"].map(auto_map)

    print("\n[Auto-Cluster] Clustered Canonical CRF Names:")
    print(refined_df[["Canonical CRF Name", "Final Canonical CRF Name"]].drop_duplicates().reset_index(drop=True))

    return refined_df

# %%
# Helper set 3 API call
async def match_heal_core_crf(client, full_prestep_response, acronym_hint=None):
    """
    Calls OpenAI to determine HEAL Core CRF match.
    Now includes acronym_hint from variable name if available.
    """

    # Build acronym line only when hint exists
    acronym_line = ""
    if acronym_hint:
        acronym_line = f"\nAcronym hint detected from variable name: {acronym_hint}\n"

    user_content = (
        f"Prestep output:\n{full_prestep_response}\n"
        f"{acronym_line}\n"
        "Please respond in strict JSON with keys "
        "\"heal_core_crf\", \"confidence\", and \"rationale\". "
        "Do not wrap in markdown or add any extra fields."
    )

    resp = await client.chat.completions.create(
        model="gpt-4.1-mini",
        messages=[
            {"role": "system", "content": matching_instruction},
            {"role": "user", "content": user_content}
        ],
        temperature=0.3
    )

    full = resp.choices[0].message.content.strip()
    print("\n--- HEAL-Match Response ---\n", full, "\n--- End ---\n")

    data = json.loads(full)
    match = data.get("heal_core_crf", "No CRF match").strip()
    conf = data.get("confidence", "Low Confidence").strip()
    rationale = data.get("rationale", "").strip()
    return match, conf, rationale

async def match_with_retry(client, full_response, acronym_hint, tries=5):
    backoff = 1
    for attempt in range(1, tries + 1):
        try:
            return await match_heal_core_crf(client, full_response, acronym_hint)
        except Exception as e:
            msg = str(e).lower()
            is_rate = (
                "rate limit" in msg or
                "429" in msg or
                (hasattr(e, "code") and e.code == "rate_limit_exceeded")
            )

            if is_rate:
                print(f"[rate limit] match attempt {attempt}, sleeping {backoff}s")
            else:
                print(f"[warning] match failed attempt {attempt}: {e}")

            if attempt == tries:
                return "No CRF match", "Low Confidence", ""

            await asyncio.sleep(backoff)
            backoff *= 2

# Loop over prestep outputs
async def run_heal_match(client, df, chunk_size=50):
    all_match, all_conf, all_mrat = [], [], []

    for start in range(0, len(df), chunk_size):
        chunk = df.iloc[start:start+chunk_size]

        tasks = [
            match_with_retry(
                client,
                row["Full Response"],
                row["CDE Acronym Finder"]   # <-- NEW: pass acronym hint
            )
            for _, row in chunk.iterrows()
        ]

        results = await asyncio.gather(*tasks)
        matches, confs, mrats = zip(*results)

        all_match.extend(matches)
        all_conf.extend(confs)
        all_mrat.extend(mrats)

        await asyncio.sleep(1)

    df["HEAL Core CRF Match"], df["Confidence Level"], df["Match Rationale"] = \
        all_match, all_conf, all_mrat

    return df

# %%
# Orchestrator
async def main():

    full_input_df = pd.read_excel(input_file, sheet_name=input_worksheet)

    data_dict_df = full_input_df[[crf_column, variable_column, description_column]].copy()

    # STEP 2 — acronym finder
    data_dict_df["CDE Acronym Finder"] = data_dict_df[variable_column].apply(detect_heal_cde_acronym)

    print("\n[CDE Acronym Finder] Preview:")
    print(data_dict_df[[variable_column, "CDE Acronym Finder"]].head(10).to_string(index=False))

    # STEP 3 — prestep (refinement)
    refined_df = await run_prestep(client, data_dict_df, chunk_size=50)

    # carry acronym forward
    refined_df["CDE Acronym Finder"] = data_dict_df["CDE Acronym Finder"].values

    # STEP 4 — harmonizer
    refined_df = await harmonize_crf_names_step(client, refined_df, batch_size=20)

    # Merge back into full DF
    enhanced_df = full_input_df.join(
        refined_df[[
            "Refined CRF Name",
            "Canonical CRF Name",
            "Rationale",
            "Full Response",
            "CDE Acronym Finder"
        ]],
        how="left"
    )

    # STEP 5 — HEAL core matcher
    final_df = await run_heal_match(client, enhanced_df, chunk_size=50)

    # Harmonize "No CRF match"
    mask = final_df["HEAL Core CRF Match"] == "No CRF match"
    final_df.loc[mask, "Confidence Level"] = "No CRF match"

    # Build metadata table
    metadata_df = (
        refined_df[
            [crf_column, "Canonical CRF Name", "Rationale", "Full Response"]
        ]
        .drop_duplicates(subset=[crf_column, "Canonical CRF Name"])
        .reset_index(drop=True)
    )

    # Save
    output_file = config["Files"]["output_file"]
    with pd.ExcelWriter(output_file, engine="xlsxwriter") as writer:
        metadata_df.to_excel(writer, sheet_name="Metadata", index=False)
        final_df.to_excel(writer, sheet_name="EnhancedDD", index=False)

    print(f"Results saved to {output_file} with sheets 'Metadata' and 'EnhancedDD'")

await main()
# Out:
# [CDE Acronym Finder] Preview:
#  Variable / Field Name CDE Acronym Finder
#                    pid               None
#                    mrn               None
#               acrostic               None
#         interview_date               None
#            interviewer               None
#  eligibility_interview               None
#     permission_reasons               None
# diagnosed_fibromyalgia               None
#                 par_q2               None
#              head_ache               None
#
# --- Full Prestep Response ---
#  {"crf_name":"Phone Screening","rationale":"The variable relates to headache symptoms collected during initial participant contact, fitting the Phone Screening form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Eligibility Screening Interview","rationale":"The variable and description indicate an initial phone-based eligibility assessment, matching the purpose of an eligibility screening interview form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Psychiatric History","rationale":"The variable pertains to psychiatric diagnoses collected during initial screening, fitting the Psychiatric History form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Demographics","rationale":"MRN (Medical Record Number) is typically collected in the Demographics form rather than during phone screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Eligibility Screening","rationale":"The variable assesses future surgery plans relevant to participant eligibility, fitting the Eligibility Screening form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Contact Information and Screening","rationale":"The variable relates to initial contact capabilities assessed during phone screening, indicating the form is for contact and screening purposes."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline_Pain_Assessment","rationale":"The variable measures the number of painful body sites, which aligns with baseline pain evaluation rather than a phone screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical_Examination","rationale":"The variable 'chest' indicates a physical assessment, best captured in the Physical Examination CRF rather than the Phone Screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"General Activity Assessment","rationale":"The variable 'gen_ac' referring to 'General Activity' aligns with a form focused on assessing general activity levels rather than a phone screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Phone Screening","rationale":"The variable 'pid' as Participant ID aligns with the 'Phone Screening' form used for initial participant identification."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical_Examination","rationale":"The variable pertains to a physical assessment of the lower leg/foot, which aligns with the Physical Examination form rather than the Phone Screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical Examination","rationale":"The variable 'knee_r' referring to the right knee aligns with physical assessment data typically collected in the Physical Examination CRF rather than the Phone Screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Phone Screening","rationale":"The variable 'arm_l' and original form name 'phone_screening' indicate this data is collected during the initial phone screening phase."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Suicidal Ideation Assessment","rationale":"The variable assesses current suicidal thoughts, aligning with a form specifically focused on suicidal ideation rather than a general phone screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Phone Screening","rationale":"The variable 'acrostic' is part of the initial participant identification collected during the Phone Screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical_Exam","rationale":"The variable relates to a physical assessment of the left elbow and hand, which is typically recorded in a Physical Exam form rather than a Phone Screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical Activity Readiness Questionnaire (PAR-Q)","rationale":"Variable 'par_q6' aligns with the PAR-Q form, which assesses medical conditions affecting physical activity readiness, including inflammatory arthritis."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical_Examination","rationale":"The variable 'elbow_hand_r' refers to a physical assessment of the right elbow and hand, which fits within the scope of a Physical Examination CRF rather than a Phone Screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to normal work activities typically assessed during initial baseline data collection."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Randomization and Treatment Assignment","rationale":"The variable 'arm_r' indicating 'Arm R' corresponds to treatment group assignment, typically captured in the Randomization and Treatment Assignment CRF rather than Phone Screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Patient Questionnaire","rationale":"The variable 'enjoy_life' assessing enjoyment of life aligns with baseline patient-reported outcomes typically collected in the Baseline Patient Questionnaire rather than a phone screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medication History","rationale":"The variable pertains to current medication usage, fitting the Medication History CRF rather than a Phone Screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Mood Assessment","rationale":"The variable 'mood_b' and description 'B. Mood' within 'phone_screening' suggests an initial mood evaluation at baseline during the phone screening phase."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Pain Assessment","rationale":"The variable relates to counting painful body sites, which aligns with pain assessment rather than phone screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical_Examination","rationale":"The variable 'hip_l' refers to the left hip, which is typically assessed during a physical examination rather than phone screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Pain_Assessment","rationale":"The variable 'average_pain' and description about pain over the last week indicate it belongs to a Pain Assessment form rather than a general phone screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Phone Screening","rationale":"The variable 'interviewer' paired with the original form name 'phone_screening' clearly indicates the form is the Phone Screening CRF."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Brief Pain Inventory","rationale":"The variable 'bpi_pain_intensity' directly references the Brief Pain Inventory, indicating this CRF captures pain intensity measures from the BPI instrument."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Brief Pain Inventory","rationale":"The variable relates to BPI pain interference, indicating it belongs to the Brief Pain Inventory CRF rather than the general phone screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Demographics and Social History","rationale":"The variable relates to personal relationships, fitting the Demographics and Social History form rather than a phone screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Phone Screening Form","rationale":"The variable pertains to reasons for non-participation during initial contact, aligning with phone screening context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Brief Pain Inventory","rationale":"The variable name includes 'bpi' and measures global pain severity, indicating it belongs to the Brief Pain Inventory CRF rather than the general phone screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Demographics","rationale":"The variable about age eligibility typically belongs to the Demographics form, which collects basic participant information like age."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical_Examination","rationale":"The variable pertains to a physical assessment of the lower leg and foot, which aligns with data typically collected during a physical examination rather than a phone screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Pain Assessment","rationale":"The variable 'pain_now' indicates current pain level, which aligns with a Pain Assessment form rather than a Phone Screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Phone Screening","rationale":"The variable 'sleep_f' labeled as 'F. Sleep' aligns with a section in the Phone Screening form focused on sleep assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical Function Assessment","rationale":"The variable 'walk_c' indicating walking ability aligns with physical function evaluation, which is typically captured in a Physical Function Assessment form rather than a phone screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical_Exam","rationale":"The variable 'knee_l' refers to a physical assessment of the left knee, which is typically collected during a physical examination rather than during phone screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Pain Assessment","rationale":"The variable 'worst_pain' describing pain intensity aligns with the Pain Assessment CRF rather than a Phone Screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical_Examination","rationale":"The variable 'Back' refers to a physical body part assessment, which is typically captured in the Physical Examination CRF rather than in a Phone Screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical_Exam","rationale":"The variable 'shoulder_r' indicates a physical assessment of the right shoulder, which aligns with data typically collected in a Physical Exam form rather than a phone screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Eligibility Screening","rationale":"The variable pertains to screening eligibility criteria regarding disability status during initial participant assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Pain Assessment","rationale":"The variable 'least_pain' refers to pain levels over the past week, which aligns with a Pain Assessment form rather than a Phone Screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical_Examination","rationale":"The variable 'shoulder_l' refers to a physical assessment of the left shoulder, which aligns with data collected during a physical examination rather than a phone screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical_Examination","rationale":"The variable 'neck' relates to a physical assessment, which is typically captured in the Physical Examination CRF rather than the Phone Screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Phone Screening","rationale":"The variable 'interview_date' and original form name 'phone_screening' clearly indicate the form captures phone screening interview details."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical_Activity_Readiness_Questionnaire","rationale":"The variable 'par_q2' aligns with the Physical Activity Readiness Questionnaire, which commonly assesses pain duration as part of screening physical readiness."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Eligibility Screening","rationale":"The variable pertains to assessing cancer diagnosis status for eligibility, aligning with screening criteria collected during initial eligibility assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical Examination","rationale":"Variable 'hip_r' refers to right hip assessment, which is typically recorded in the Physical Examination form rather than Phone Screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medical_History","rationale":"The variable pertains to a past diagnosis of fibromyalgia, which is typically captured in a medical history form rather than a phone screening focused on initial eligibility questions."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medication History","rationale":"The variable pertains to current medication use, fitting the Medication History CRF rather than Phone Screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medication History","rationale":"Variable pertains to stable medication use, which is typically captured in the Medication History form rather than the Phone Screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medication History","rationale":"The variable pertains to current use of specific medications, fitting the Medication History form rather than Phone Screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medications","rationale":"The variable pertains to current medication use, aligning with the Medications CRF rather than the Phone Screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medication History","rationale":"The variable pertains to current use of specific medications, fitting the Medication History CRF rather than the initial Phone Screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Demographics","rationale":"Ethnicity questions like Hispanic or Latino status are typically collected in the Demographics CRF rather than a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Visit Log","rationale":"The variable 'date_of_visit' typically belongs to forms tracking visit details, which is best captured by the Visit Log CRF rather than Baseline Assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable pertains to initial participant information about employment status, aligning with baseline assessment data collection."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Demographics","rationale":"Marital status is a standard demographic variable typically collected in the Demographics CRF rather than a Baseline Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Informed_Consent","rationale":"The variable pertains to participant consent regarding the use and destruction of audiotapes, aligning with informed consent documentation."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Psychiatric Assessment","rationale":"The variable 'easy_annoyed' relates to mood or psychiatric symptoms assessed at baseline, fitting the Baseline Psychiatric Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Informed Consent Form","rationale":"The variable relates to participant agreement and authorization to participate, which is documented in the Informed Consent Form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain Assessment","rationale":"Variable 'worst_pain_baseline' measuring worst pain in the last week aligns with a baseline pain-focused assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Phone Screening Form","rationale":"The variable 'phone_number' with the original form name 'phone_screening' clearly corresponds to the Phone Screening Form, which collects contact details during initial screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable references mental health professionals typically assessed at study baseline, matching the Baseline Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Demographics","rationale":"The variable relates to socioeconomic status collected at study start, fitting the Baseline Demographics form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Phone Screening","rationale":"The variable 'eligible_for_study' and the description align with initial eligibility assessment typically captured in the Phone Screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medical_History","rationale":"The variable 'orthopedist' relates to specialist medical history typically captured in a Medical History CRF rather than a Baseline Assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Anxiety Assessment","rationale":"The variable relates to anxiety symptoms, indicating it belongs to an anxiety-focused baseline assessment rather than a general baseline form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'massage' is part of the initial evaluation, fitting the Baseline Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medical_History","rationale":"The variable 'chiropractor' relates to prior medical care, fitting within the Medical History form rather than a generic baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain Assessment","rationale":"The variable relates to the duration of pain at baseline, fitting the Baseline Pain Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'options_other' labeled as 'j. Other' indicates an 'Other' option in a baseline assessment questionnaire, matching the original form name Baseline Assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Mental Health Assessment","rationale":"The variable 'trouble_relaxing' relates to mental health symptoms typically assessed at baseline, indicating the form captures initial mental health status."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Informed_Consent","rationale":"The variable relates to participant consent for use of audiotapes in future studies, which is typically captured in the Informed Consent form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Phone Screening","rationale":"The variable relates to scheduling contact preferences, aligning with initial participant contact captured in the Phone Screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'gad7_function' relates to GAD-7 Anxiety, which is typically assessed during the baseline assessment phase."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Demographics","rationale":"Date of birth is a core demographic variable typically collected in the Demographics CRF rather than a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Demographics","rationale":"Education level is typically collected in the Demographics form, which captures baseline participant characteristics."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medication History","rationale":"The variable pertains to stable dosing of specific medications, indicating it belongs to a form capturing medication use history rather than initial screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Phone Screening Form","rationale":"The variable 'comments' paired with the original form name 'phone_screening' clearly indicates it belongs to the Phone Screening Form capturing notes during initial participant contact."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Physical_Therapy_Assessment","rationale":"The variable 'pt' refers to Physical Therapy, which aligns with a form focused on assessing physical therapy status or interventions."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Demographics","rationale":"Gender is a standard demographic variable typically collected in the Demographics CRF rather than a baseline assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Demographics","rationale":"The variable pertains to self-identified race, which is typically collected in the Demographics CRF rather than a general Baseline Assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Phone Screening","rationale":"The variable 'result' with the description 'This patient is:' aligns with the 'Phone Screening' form, which typically captures initial patient eligibility or status information."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Concomitant Medications","rationale":"The variable 'treatment_other' and prompt 'Please specify' typically relate to recording additional treatments or medications, which aligns with the Concomitant Medications CRF rather than Baseline Assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Contact Information Form","rationale":"The variable 'email' under 'phone_screening' aligns with collecting participant contact details, which is typically captured in a Contact Information Form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Mental Health Assessment","rationale":"The variable describes a mental health symptom assessed at baseline, aligning with a baseline mental health-focused form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Pain Medication Use Assessment","rationale":"The variable pertains to current use of specific pain medications, fitting a form focused on assessing pain medication usage rather than screening or other domains."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'acupuncture' is part of initial patient data collection, fitting the Baseline Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Phone Screening","rationale":"The variable 'eligible' and the description about determining study eligibility during initial contact aligns with the Phone Screening form purpose."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Demographics","rationale":"Age at enrollment is typically collected in the Demographics form rather than a general Baseline Assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medication History","rationale":"The variable assesses current medication usage, fitting the Medication History CRF rather than a Phone Screening form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Psychiatric Assessment","rationale":"The variable describes an anxiety-related feeling typically assessed during baseline psychiatric evaluations."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medication History","rationale":"The variable pertains to current medication usage, which aligns with medication history data collection rather than a phone screening."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'pain_clinic' is part of the baseline assessment capturing initial patient information related to pain management settings."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Behavior Assessment","rationale":"The variable 'sit_still' relates to restlessness, fitting a behavioral evaluation at baseline."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'neurologist' relates to initial clinical evaluation, matching the context of the Baseline Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Mental Health Assessment","rationale":"The variable relates to worry, a mental health symptom, aligning with baseline mental health evaluation rather than general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'rheumatologist' pertains to initial clinical evaluation, fitting the Baseline Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable description reflects baseline patient status, aligning with the Baseline Assessment form capturing initial condition evaluations."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Cognitive Assessment","rationale":"The variable describes concentration difficulties, indicating a cognitive function evaluation typically assessed at baseline."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"PHQ-9 Depression Scale","rationale":"The variable describes a core symptom of depression commonly assessed by the PHQ-9 instrument."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Depression Assessment","rationale":"The variable reflects a subjective emotional state consistent with depression symptoms typically assessed at baseline."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to normal work activities assessed at study entry, fitting the Baseline Assessment form's purpose."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to baseline quality of life measures, matching the original form name 'baseline_assessment'."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'right_now_baseline' aligns with capturing immediate status at study start, matching the 'Baseline Assessment' form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'c_walking_ability' corresponds to a functional status measure typically collected during initial patient evaluation, matching the Baseline Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'average_baseline' and original form name 'baseline_assessment' indicate this variable pertains to initial status measurements collected during the baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Mental Health Assessment","rationale":"The variable 'feel_down' relates to mood evaluation at baseline, fitting the mental health assessment context within the baseline assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Patient Reported Outcomes","rationale":"The variable assesses baseline fatigue levels, fitting patient-reported outcomes collected at baseline."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"Variable 'fatigue_total' aligns with baseline symptom evaluation typically captured in the Baseline Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain and Symptom Assessment","rationale":"The variable relates to patient fear about pain worsening, fitting a baseline assessment of pain and symptoms."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable pertains to social relations assessed at study start, aligning with the Baseline Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Functional Assessment","rationale":"The variable assesses baseline physical ability, fitting the context of a baseline functional evaluation form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Functional_Abilities_Assessment","rationale":"The variable assesses physical function related to stair mobility, aligning with functional abilities evaluation rather than a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'rumination' is part of the initial psychological evaluation, consistent with the Baseline Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'poor_eating' describing appetite issues aligns with general health and baseline status captured in the Baseline Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"PHQ-9_Depression_Assessment","rationale":"The variable 'let_down' corresponds to a PHQ-9 depression symptom question typically collected in a depression assessment form, not a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain Assessment","rationale":"The variable describes a pain-related thought at baseline, aligning with a baseline pain assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Mental Health Assessment","rationale":"The variable relates to a mental health concern expressed at baseline, aligning with a Baseline Mental Health Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Pain_Assessment","rationale":"The variable pertains to rating pain over time, which aligns with a specialized Pain Assessment form rather than a general Baseline Assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline_Symptom_Assessment","rationale":"The variable reflects a baseline emotional response to pain, fitting a symptom or baseline assessment form rather than a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'pain' and its description about worry regarding pain aligns with baseline assessments capturing initial patient-reported symptoms and concerns."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'b_mood' with description 'B. Mood' aligns with baseline mood evaluation typically collected in the Baseline Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline_Assessment","rationale":"The variable relates to baseline fatigue impacting task initiation, fitting the Baseline Assessment form focused on initial participant status."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable describes baseline psychomotor activity, fitting the Baseline Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'magnification_sum' relates to baseline measurements, matching the original form name 'baseline_assessment' which collects initial assessment data."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'tired_energy' aligns with baseline symptom assessment captured in the Baseline Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Mental Health Assessment","rationale":"The variable reflects a mental or psychological symptom assessed at baseline, fitting a mental health-focused baseline assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'f_sleep' with description 'F. Sleep' corresponds to section F in the Baseline Assessment form, indicating sleep-related baseline data."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Psychosocial Assessment","rationale":"The variable reflects a psychological state assessed at baseline, fitting the Baseline Psychosocial Assessment form rather than a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'a_general_activity' corresponds directly to the 'Baseline Assessment' form indicated by the original form name and the description of general activity at baseline."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Psychological Assessments","rationale":"The variable 'helplessness_sum' pertains to a psychological measure typically collected in a psychological or mental health assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to sleep issues assessed during initial patient evaluation, fitting the Baseline Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Functional Assessment","rationale":"The variable assesses ability to perform chores, fitting the baseline functional status evaluation context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {
#   "crf_name": "SF-36 Health Survey",
#   "rationale": "PCS Total refers to the Physical Component Summary score from the SF-36 Health Survey, commonly collected at baseline."
# }
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'feel' related to fatigue aligns with initial patient status captured in the Baseline Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Functional Assessment","rationale":"The variable relates to daily living activities assessed at baseline, fitting a functional status evaluation form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'rundown' and original form name 'baseline_assessment' indicate an initial overall health or wellness evaluation, matching the Baseline Assessment CRF."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'phy_function' related to PROMIS Physical Function aligns with baseline functional status collected in the Baseline Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Quality of Life Assessment","rationale":"The description reflects a subjective quality of life or symptom burden measure typically captured at baseline."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"PHQ-9 Depression Assessment","rationale":"The variable reflects a depressive symptom from the PHQ-9 scale, commonly captured in the depression assessment form rather than a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain Assessment","rationale":"The variable relates to the Brief Pain Inventory measured at baseline, indicating a baseline pain-focused assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Brief Pain Inventory (BPI)","rationale":"The variable name and description reference the BPI Pain Intensity total, indicating it belongs to the Brief Pain Inventory form rather than a generic baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'sleep_quality' aligns with general health and lifestyle data typically collected during the Baseline Assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Pain_Assessment","rationale":"The variable relates to managing pain intensity, fitting the context of a Pain Assessment form rather than a general Baseline Assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'least_baseline' and original form name 'baseline_assessment' indicate this variable is part of the Baseline Assessment CRF capturing baseline conditions."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Patient_Health_Questionnaire","rationale":"PHQ8 refers to the Patient Health Questionnaire 8-item depression scale, indicating the variable belongs to the Patient Health Questionnaire form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"PTSD_Symptom_Assessment","rationale":"The variable description refers to intrusive thoughts about painful events, aligning with PTSD symptom evaluation rather than a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to a baseline behavior description captured during initial patient assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'social_total' aligns with social domain data typically collected during the initial baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to social activities and functional status, fitting the Baseline Assessment's scope of initial participant evaluation."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to sleep problems reported at study start, fitting the Baseline Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to sleep difficulty reported at baseline, matching the Baseline Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Sleep_Quality_Assessment","rationale":"The variable 'refreshing' related to sleep quality indicates it belongs to a form assessing sleep patterns and quality."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable assesses baseline pain impact on social activities, fitting the Baseline Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Sleep_Questionnaire","rationale":"The variable relates to sleep-related impairment, which is typically captured in dedicated sleep or patient-reported outcome questionnaires rather than a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to a baseline pain behavior assessment, matching the original form name exactly."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Sleep Quality Assessment","rationale":"The variable relates to daytime sleepiness, fitting the thematic focus of sleep quality rather than a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Functional Assessment","rationale":"The variable relates to difficulty in leisure activities, fitting within a baseline functional status evaluation."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to baseline cognitive effects of sleep, matching the baseline assessment context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to baseline functional status regarding family activities, fitting the Baseline Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'day_sleep' measuring daytime sleepiness fits the Baseline Assessment context capturing initial participant status."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain Assessment","rationale":"The variable relates to pain behavior at baseline, indicating it belongs to a Baseline Pain Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Functional Status","rationale":"The variable relates to difficulty performing usual work, indicating baseline functional ability assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain Assessment","rationale":"The variable relates to pain behavior at baseline, matching the Baseline Pain Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to initial physical status and pain-related posture changes, fitting the Baseline Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to baseline patient-reported sleep problems, fitting the Baseline Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Sleep Disturbance Assessment","rationale":"The variable relates specifically to sleep disturbance, indicating it belongs to a dedicated Sleep Disturbance Assessment form rather than a general Baseline Assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain Assessment","rationale":"The variable relates to discussing pain during baseline, indicating it belongs to a pain-focused baseline assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medical_History","rationale":"The variable relates to chronic respiratory conditions typically captured in a patient's medical history rather than baseline assessments."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain Assessment","rationale":"The variable 'painav' relates to average pain rating at baseline, aligning with a Baseline Pain Assessment form rather than a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to a baseline self-report measure of mood and sleep, matching the Baseline Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable assesses baseline pain interference at home, fitting the Baseline Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medical_History","rationale":"The variable describes prior heart conditions, which are typically captured in the Medical History form rather than a general Baseline Assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Psychosocial Assessment","rationale":"The variable relates to behavioral responses to pain, fitting a baseline psychosocial evaluation rather than a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain Assessment","rationale":"The variable 'grimace' relates to pain expression, fitting the Baseline Pain Assessment context rather than a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to baseline pain interference, matching the Baseline Assessment form focused on initial patient status."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to baseline measurement of pain interference, matching the original form name focused on initial participant assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medical_History","rationale":"The variable 'liver' referring to liver disease aligns with medical history data collected at baseline."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to baseline patient behavior during pain, aligning with the Baseline Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'pain_inter' relates to Pain Interference measured at baseline, matching the 'Baseline Assessment' form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Neurological_History","rationale":"The variable pertains to neurological conditions, aligning with a form focused on capturing neurological history rather than a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain Assessment","rationale":"The variable relates to pain and behavior during pain at baseline, fitting the Baseline Pain Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Pain Impact Assessment","rationale":"The variable relates to how pain affects daily activities, fitting the Pain Impact Assessment form rather than a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Pain Behavior Assessment","rationale":"The variable 'painbehavior_total' relates specifically to pain behavior measures, indicating a form dedicated to assessing pain-related behaviors rather than a general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain Assessment","rationale":"The variable relates to pain and help-seeking behavior at baseline, aligning with a Baseline Pain Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain and Behavior Assessment","rationale":"The variable 'squirm' relates to pain behavior observed at baseline, matching the Baseline Pain and Behavior Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain Assessment","rationale":"The variable relates to pain management comfort methods at baseline, fitting the Baseline Pain Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to a subjective feeling at baseline, fitting the Baseline Assessment form context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable relates to baseline functional status during pain, matching the original 'baseline_assessment' form focused on initial patient condition."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain Assessment","rationale":"The variable relates to a pain response behavior recorded at baseline, aligning with a Baseline Pain Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Assessment","rationale":"The variable 'tired_sleep' indicating feeling tired aligns with baseline patient-reported symptoms captured in the Baseline Assessment form."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Sleep and Fatigue Assessment","rationale":"The variable relates to difficulty due to sleepiness, fitting a baseline form assessing sleep and fatigue symptoms."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Pain_Assessment","rationale":"The variable describes facial expression related to pain, which aligns with a Pain Assessment form rather than a general Baseline Assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Functional Assessment","rationale":"The variable relates to a baseline functional behavior involving pain and movement, fitting a baseline functional assessment context."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Medical History","rationale":"Hypertension is a baseline medical condition typically collected in the Baseline Medical History form rather than a generic baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Baseline Pain Assessment","rationale":"The variable relates to muscle tension during pain, fitting within baseline pain evaluation rather than general baseline assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medical History","rationale":"The variable relates to a pre-existing condition (high blood sugar/diabetes), which is typically captured in the Medical History form rather than a Baseline Assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medication_Administration","rationale":"Tramadol is a medication, so it is best captured under a Medication Administration form rather than a Baseline Assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
#  {"crf_name":"Medication Administration","rationale":"The variable refers to a specific medication (Meperidine/Demerol), which is typically recorded in a Medication Administration form rather than a Baseline Assessment."}
# --- End ---
#
#
# --- Full Prestep Response ---
# ...
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Adverse Event' does not exactly match any HEAL Core CRF names in the vector store."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Drug Accountability Log' and variables related to drug accountability do not correspond to any HEAL Core CRF names or their domains."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicide Assessment Form' does not exactly match any HEAL Core CRF names, and the variable description does not correspond to any listed HEAL Core CRF domains."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Drug Accountability Log' and variable description do not correspond to any HEAL Core CRF names or their domains."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Adverse Event Form' does not exactly match any HEAL Core CRF names in the vector store."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicide Risk Assessment' does not exactly match any HEAL Core CRF names in the vector store."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicidality Assessment' does not exactly match any HEAL Core CRF names, and no HEAL Core CRF explicitly covers suicidality."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Adverse Event' does not exactly match any HEAL Core CRF name, and the variable description does not reinforce any domain from the HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicide Risk Assessment' does not exactly match any HEAL Core CRF names, and the description does not reinforce any domain from the HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Participant Status Form' does not exactly match any HEAL Core CRF names and the description does not reinforce any domain from the HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicide Risk Assessment' does not exactly match any HEAL Core CRF name, and no listed HEAL Core CRF covers suicide risk specifically."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Adverse Event' does not exactly match any HEAL Core CRF names, and the variable description does not reinforce any domain from the HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicidality Assessment' does not exactly match any HEAL Core CRF names, and the description does not reinforce any domain from the listed HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Drug Accountability Log' does not exactly match any HEAL Core CRF names, and the description does not reinforce any domain from the HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Drug Accountability Log' does not exactly match any HEAL Core CRF names, and the description does not reinforce any domain from the HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicide Assessment Form' does not exactly match any HEAL Core CRF name and the description does not align with any listed HEAL Core CRF domains."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicide Assessment' does not exactly match any HEAL Core CRF name, and no description indicates alignment with the listed HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Participant Status and Visit Disposition' does not exactly match any HEAL Core CRF name and the description does not align with any listed HEAL Core CRF domains."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Drug Accountability Log' does not exactly match any HEAL Core CRF names and the description does not indicate alignment with any listed HEAL Core CRF domains."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicide Risk Assessment' does not exactly match any HEAL Core CRF names and the description does not reinforce any domain from the HEAL Core CRFs list."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicide Risk Assessment' does not exactly match any HEAL Core CRF names, and the variable description does not reinforce any domain from the HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Drug Accountability Log' and its description about tracking medication adherence do not exactly match any HEAL Core CRF names or their domains."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicide Risk Assessment' does not exactly match any HEAL Core CRF names, and the description focuses on suicide risk, which is not covered by listed HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicide Risk Assessment' does not exactly match any HEAL Core CRF names, and the description does not reinforce any domain from the HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicide Risk Assessment' does not exactly match any HEAL Core CRF names and the description does not reinforce any domain from the HEAL Core CRFs list."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicidality Assessment' does not exactly match any HEAL Core CRF names, and the description focuses on suicidality which is not covered by the listed HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicide Risk Assessment' does not exactly match any HEAL Core CRF name, and the description does not reinforce any domain from the HEAL Core CRFs list."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Subject Identification Form' does not exactly match any HEAL Core CRF names and the variable description does not reinforce any HEAL Core CRF domain."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Drug Accountability Log' does not exactly match any HEAL Core CRF names, and the description relates to medication tracking, which is not covered by any listed HEAL Core CRF."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Suicidal Ideation Assessment' does not exactly match any HEAL Core CRF names, and the description focuses on suicidal thoughts, which is outside the scope of listed HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Living_Situation_Assessment' and variable 'live_alone' do not match any HEAL Core CRF names or their described domains."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Adverse Event' does not exactly match any HEAL Core CRF names and the description does not reinforce any specific HEAL Core CRF domain."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"Demographics","confidence":"High","rationale":"The CRF name exactly matches 'Demographics' and the rationale mentions age collection consistent with demographic data."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Adverse Event' does not exactly match any HEAL Core CRF name, and the variable description does not reinforce any domain from the HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Adverse Event' does not exactly match any HEAL Core CRF names, and the description does not reinforce any domain from the HEAL Core CRFs list."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Serious Adverse Event' does not exactly match any HEAL Core CRF name in the vector store."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Serious Adverse Event Form' does not exactly match any HEAL Core CRF names and the description does not reinforce any domain from the HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Adverse Event' does not exactly match any HEAL Core CRF names, and the variable description does not reinforce any domain from the HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name and variable focus on study completion reasons, which do not correspond to any HEAL Core CRF names or their domains."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"CRF name and variable description indicate investigator details, which do not correspond to any HEAL Core CRF focused on patient-reported outcomes or clinical assessments."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Serious Adverse Event Form' does not exactly match any HEAL Core CRF names and the description does not reinforce any domain from the HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Study Evaluation Form' and description about participant feedback on treatment do not exactly match any HEAL Core CRF names or their domains."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Treatment_Evaluation_Form' does not exactly match any HEAL Core CRF names, and the description is too generic to link to a specific HEAL Core CRF."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Study Evaluation Form' does not exactly match any HEAL Core CRF names and the description does not reinforce any specific HEAL Core CRF domain."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Treatment_Evaluation' does not exactly match any HEAL Core CRF names, and the description does not reinforce any domain of the listed HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Serious Adverse Event' does not exactly match any HEAL Core CRF names in the vector store."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Serious Adverse Event Form' does not exactly match any HEAL Core CRF names, and the description does not reinforce any domain from the HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Serious Adverse Event' does not exactly match any HEAL Core CRF names and the description does not reinforce any domain from the HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Study Evaluation Form' does not exactly match any HEAL Core CRF names and the description about feedback on the treatment program does not align with any specific HEAL Core CRF domain."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Investigator Signature Form' does not exactly match any HEAL Core CRF names and the description indicates it is about investigator approvals, not related to any HEAL Core CRF domain."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Study Evaluation Form' does not exactly match any HEAL Core CRF names and the description about participant satisfaction does not align specifically with any listed HEAL Core CRF domains."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"Demographics","confidence":"High","rationale":"The CRF name exactly matches 'Demographics' and the variable description about sex aligns with demographic data collection."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Serious Adverse Event' does not exactly match any HEAL Core CRF names, and the description does not align with any listed HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Serious Adverse Event' does not exactly match any HEAL Core CRF names in the vector store."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Serious Adverse Event' does not exactly match any HEAL Core CRF names, and the description does not reinforce any specific HEAL Core CRF domain."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Serious Adverse Event' does not exactly match any HEAL Core CRF names and the description does not align with any listed HEAL Core CRF domains."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Study Evaluation Form' does not exactly match any HEAL Core CRF name and the description about participant feedback on treatment program does not align with any specific HEAL Core CRF domain."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Study Completion' does not exactly match any HEAL Core CRF names and the description does not reinforce any domain from the HEAL Core CRFs."}
# --- End ---
#
#
# --- HEAL-Match Response ---
#  {"heal_core_crf":"No CRF match","confidence":"High","rationale":"The CRF name 'Study Evaluation Form' does not exactly match any HEAL Core CRF names, and the description about participant feedback on treatment program does not align with any specific HEAL Core CRF domain."}
# --- End ---
#
# Results saved to out\PRECICEV2_DataDictionary_2023-08-11_2025-11-20.xlsx with sheets 'Metadata' and 'EnhancedDD'
